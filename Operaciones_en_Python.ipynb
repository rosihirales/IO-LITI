# %% [markdown]
# <a href="https://colab.research.google.com/github/rosihirales/IO-LITI/blob/main/Operaciones_en_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Operaciones en Python![Screenshot 2023-03-17 at 12-35-44 Operadores Básicos en Python con ejemplos.png](data:image/png;base64,...)

# %% [markdown]
# # Operaciones aritméticas básicas

# %%
#Operadores aritmeticos en Python
x = 10; y = 3
print("Operadores aritméticos")
print("x+y =", x+y)   #Suma, resultado: 13
print("x-y =", x-y)   #Resta, resultado: 7
print("x*y =", x*y)   #Multiplicacion, resultado: 30
print("x/y =", x/y)   #División, resultado: 3.3333333333333335
print("x%y =", x%y)   #Módulo, resultado: 1
print("x**y =", x**y) #Exponente, resultado: 1000
print("x//y =", x//y) #Cociente, resultado: 3
# Out:
# Operadores aritméticos
# x+y = 13
# x-y = 7
# x*y = 30
# x/y = 3.3333333333333335
# x%y = 1
# x**y = 1000
# x//y = 3

# %% [markdown]
# # Orden de aplicación
#
# En los ejemplos anteriores simplemente hemos aplicado un operador a dos números sin mezclarlos entre ellos. También es posible tener varios operadores en la misma línea de código, y en este caso es muy importante tener en cuenta las prioridades de cada operador y cual se aplica primero. Ante la duda siempre podemos usar paréntesis, ya que todo lo que está dentro de un paréntesis se evaluará conjuntamente, pero es importante saber las prioridades.
#
# El orden de prioridad sería el siguiente para los operadores aritméticos, siendo el primero el de mayor prioridad:
#
#     () Paréntesis
#     ** Exponente
#     -x Negación
#     * / // Multiplicación, División, Cociente, Módulo
#     + - Suma, Resta

# %%
def operacion_sencilla(numero1, numero2, operacion):
    """
    Esta función toma dos números y una operación aritmética y devuelve el resultado
    de la operación. La operación se especifica como una cadena, que debe ser uno de
    los siguientes valores: '+', '-', '*', '/'.
    """
    if operacion == '+':
        resultado = numero1 + numero2
    elif operacion == '-':
        resultado = numero1 - numero2
    elif operacion == '*':
        resultado = numero1 * numero2
    elif operacion == '/':
        resultado = numero1 / numero2
    else:
        resultado = None

    return resultado

#Resolver la operación 4 + 3
resultado = operacion_sencilla(4, 3, '+')
print(resultado)  # Salida: 7

# Resolver la operación 9 - 6
resultado = operacion_sencilla(9, 6, '-')
print(resultado)  # Salida: 3

# Resolver la operación 5 * 2
resultado = operacion_sencilla(5, 2, '*')
print(resultado)  # Salida: 10

# Resolver la operación 12 / 4
resultado = operacion_sencilla(12, 4, '/')
print(resultado)  # Salida: 3.0
# Out:
# 7
# 3
# 10
# 3.0

# %%
#suma de números
num1 = 5
num2 = 10
resultado = num1 + num2
print(resultado) # salida: 15
# Out:
# 15

# %%
#resta de números
num1 = 20
num2 = 15
resultado = num1 - num2
print(resultado) # salida: 5

# %%
#multiplicación de dos números
num1 = 6
num2 = 7
resultado = num1 * num2
print(resultado) # salida: 42

# %%
#división de dos números
num1 = 15
num2 = 3
resultado = num1 / num2
print(resultado) # salida: 5.0
# Out:
# 5.0

# %%
#modulo o resto de una división
num1 = 20
num2 = 3
resultado = num1 % num2
print(resultado) # salida: 2
# Out:
# 2

# %%
#potencia de un numero
num = 5
potencia = 3
resultado = num ** potencia
print(resultado) # salida: 125
# Out:
# 125

# %%
#raíz cuadrada de un numero
import math
num = 16
resultado = math.sqrt(num)
print(resultado) # salida: 4.0
# Out:
# 4.0

# %%
#Operaciones combinadas
num1 = 10
num1 = 5
resultado = (num1 + num2) * num2 / num1 - num2
print(resultado) # salida: 2.5
# Out:
# 5.0

# %% [markdown]
# ## Ejercicio 1
#
# Escribir un programa que muestre por pantalla el resultado de la siguiente operación aritmética $\left(\frac{3+2}{2\cdot 5}\right)^2$.

# %%
print(((3 + 2) / (2 * 5)) ** 2)

# %% [markdown]
# # Ejercicio 2

# %%
a = 10
b = 5
c = a + b * 2 - 4 / 2
print("El resultado es:", c)
# Out:
# El resultado es: 18.0

# %% [markdown]
# # Ejercicio 3

# %%
x = 3
y = 5
z = x**2 + y**2 - (x*y)
print("El resultado es:", z)
# Out:
# El resultado es: 19

# %% [markdown]
# # Ejercicio 4

# %%
a = 8
b = 2
c = 10
d = (a + b) * c / b
print("El resultado es:", d)
# Out:
# El resultado es: 50.0

# %% [markdown]
# # Ejercicio 5

# %%
a = 10
b = 3
c = 4
d = 6
e = ((a**2 * b) - (c*3 / d)) / (a * b + c)
print("El resultado es:", e)
# Out:
# El resultado es: 8.764705882352942
